# %%
print("Welcome to the Interactive personal Data collecter!")

name = input("Enter your Name: ")
age = input("Enter your age: ")
height = float(input("Enter your height (in feet): "))
fav_num = int(input("Enter your favourite number: "))

print("\nThank you! here is Information we collected:\n")

print("Name:", name, "(Type:",type(name), ", Memory Address:", id(name), ")")
print("Age:", age, "(Type:",type(age), ", Memory Address:", id(age), ")")
print("Height:", height, "(Type:",type(height), ", Memory Address:", id(height), ")")
print("Favourite Number:", fav_num, "(Type:",type(fav_num), ", Memory Address:", id(fav_num), ")")

print("\nyour brith year is approximately:")

print("\nThank you for using the personal Data collecter. goodbye!")
# Out:
# Welcome to the Interactive personal Data collecter!
# Enter your Name:  Hiteshi
# Enter your age:  17
# Enter your height (in feet):  6.0
# Enter your favourite number:  7
# Thank you! here is Information we collected:
#
# Name: Hiteshi (Type: <class 'str'> , Memory Address: 61987688 )
# Age: 17 (Type: <class 'str'> , Memory Address: 64752688 )
# Height: 6.0 (Type: <class 'float'> , Memory Address: 57101736 )
# Favourite Number: 7 (Type: <class 'int'> , Memory Address: 3878172 )
#
# your brith year is approximately:
#
# Thank you for using the personal Data collecter. goodbye!
